# %%
# !git clone https://github.com/OpenNMT/OpenNMT-py
  
# !ls
# Out:
# fatal: destination path 'OpenNMT-py' already exists and is not an empty directory.
# available_models			  onmt
# CHANGELOG.md				  OpenNMT-py
# config					  preprocess.py
# CONTRIBUTING.md				  README.md
# data					  requirements.opt.txt
# Dockerfile				  requirements.txt
# docs					  server.py
# floyd_requirements.txt			  setup.py
# floyd.yml				  tools
# github_deploy_key_opennmt_opennmt_py.enc  train.py
# LICENSE.md				  translate.py

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/pytorch/text.git (to revision master) to /tmp/pip-req-build-1zbjcato
#   Running command git clone -q https://github.com/pytorch/text.git /tmp/pip-req-build-1zbjcato
# ...
#   Created wheel for torchtext: filename=torchtext-0.4.0-cp36-none-any.whl size=53121 sha256=afc6b4d5f75656bcfbc28227e3a6c0ebd1e2ee34598352e3c3793cf3996534cf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fenxkfmu/wheels/47/f9/8d/a9e397ec2629a3fd3219b2ebc3ec8b55396fd3cf55963a77a5
# Successfully built torchtext

# %%
# !pwd
from google.colab import files

uploaded = files.upload()
# Out:
# /content/OpenNMT-py
#      <input type="file" id="files-df882638-3b9f-4347-a8ae-916b909d5bb2" name="files[]" multiple disabled />
#      <output id="result-df882638-3b9f-4347-a8ae-916b909d5bb2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# !python preprocess.py -train_src train_src.txt -train_tgt train_dst.txt -valid_src valid_src.txt -valid_tgt valid_dst.txt -save_data data/light

# %%
# !python train.py -data data/light -save_model light -train_steps 1000000 -gpu_ranks 0
# Out:
# [2019-05-30 18:57:08,373 INFO]  * src vocab size = 40353
# [2019-05-30 18:57:08,373 INFO]  * tgt vocab size = 50004
# [2019-05-30 18:57:08,373 INFO] Building model...
# [2019-05-30 18:57:16,998 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(40353, 500, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(500, 500, num_layers=2, dropout=0.3)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50004, 500, padding_idx=1)
#         )
#       )
#     )
#     (dropout): Dropout(p=0.3)
#     (rnn): StackedLSTM(
#       (dropout): Dropout(p=0.3)
#       (layers): ModuleList(
#         (0): LSTMCell(1000, 500)
#         (1): LSTMCell(500, 500)
#       )
#     )
#     (attn): GlobalAttention(
# ...

# %%
# !ls

# !echo "Do you want to see this?" > data/src-test.txt 
# !python translate.py -model light_step_150000.pt -src data/src-test.txt -output pred.txt -verbose -replace_unk
# Out:
#  available_models			    light_step_35000.pt
#  CHANGELOG.md				    light_step_40000.pt
#  config					    light_step_45000.pt
#  CONTRIBUTING.md			    light_step_50000.pt
#  data					    light_step_5000.pt
#  Dockerfile				    light_step_55000.pt
#  docs					    light_step_60000.pt
#  floyd_requirements.txt			    light_step_65000.pt
#  floyd.yml				    light_step_70000.pt
#  github_deploy_key_opennmt_opennmt_py.enc   light_step_75000.pt
#  LICENSE.md				    light_step_80000.pt
#  light_step_100000.pt			    light_step_85000.pt
#  light_step_10000.pt			    light_step_90000.pt
#  light_step_105000.pt			    light_step_95000.pt
#  light_step_110000.pt			    onmt
#  light_step_115000.pt			    pred.txt
#  light_step_120000.pt			    preprocess.py
#  light_step_125000.pt			    README.md
#  light_step_130000.pt			    requirements.opt.txt
#  light_step_135000.pt			    requirements.txt
#  light_step_140000.pt			    server.py
#  light_step_145000.pt			    setup.py
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mkdir models
# !mv light_step_150000.pt models/light_step_150000.pt

# %%
# !cp -r models/ /content/drive/My\ Drive/checkpoint

# %%
# !CUDA_VISIBLE_DEVICES=1 python train.py -data data/demo -gpu_ranks 0 -save_model demo-model -world_size 1 \
        -layers 6 -rnn_size 512 -word_vec_size 512 -transformer_ff 2048 -heads 8  \
        -encoder_type transformer -decoder_type transformer -position_encoding \
        -train_steps 200000  -max_generator_batches 2 -dropout 0.1 \
        -batch_size 4096 -batch_type tokens -normalization tokens  -accum_count 2 \
        -optim adam -adam_beta2 0.998 -decay_method noam -warmup_steps 8000 -learning_rate 2 \
        -max_grad_norm 0 -param_init 0  -param_init_glorot \
        -label_smoothing 0.1 -valid_steps 5000 -save_checkpoint_steps 5000 -train_from demo-model_step_20000.pt

# %%
# !ls
